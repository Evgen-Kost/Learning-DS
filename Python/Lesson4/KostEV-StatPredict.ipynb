# %% [markdown]
# # Практика
# Используемые библиотеки

# %%
import pandas as pd
import numpy as np
import requests
import io
import re
import warnings
warnings.filterwarnings('ignore')

# Эта команда позволяет вывыводить результаты друг за другом без вызова print
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Загрузка DataFrame
# ### Задача 1
# На основании данных портала "Открытые данные России" о результатах Химического анализа родника в Нескучном саду https://data.gov.ru/opendata/7708660670-rodnik-neskuchniy-sad
# средствами библиотеки __Pandas__ сформируйте поле выводов по каждому анализирумомому параметру.
# Например, по показателю _pH_ получен результат _8.4 единицы pH_ при нормативе от _6 до 9 единиц pH_. Т.о. по данному показателю результат анализа в норме.
# Для решения задачи необходимо программно "прочитать и понять" значение столбца "Норматив" и выделенное численное значение сравнить с нормативом согласно логике норматива. Например, __6 >= pH >= 9__.
# В итоговом DataFrame столбец "Показатель" сделайте индексным.
#
#
# Загзрузка DataFrame выполняется непосредственно c сайта "Открытые данные России" https://data.gov.ru/opendata/7708660670-rodnik-neskuchniy-sad/data-20160608T1215-structure-20160608T1215.csv (см. код ниже).

# %%
df=pd.read_csv("Химический анализ родника в Нескучном саду.csv", sep=';')
display(df)
# Out:
#                                Показатель Единица измерений  \
# 0                                      pH        единицы pH
# 1                                   Запах             баллы
# 2                               Цветность           градусы
# 3                               Жёсткость       мг-эквл/дм3
# 4         Аммиак и аммоний-ион (по азоту)            мг/дм3
# 5                        Нитриты (по NO2)            мг/дм3
# 6                        Нитраты (по NO3)            мг/дм3
# 7                             Фосфаты (P)            мг/дм3
# 8                            Хлориды (Cl)            мг/дм3
# 9                          Сульфаты (SO4)            мг/дм3
# 10  Железо (включая хлорное железо) по Fe            мг/дм3
# 11                                  Нефть            мг/дм3
# 12    Общая минерализация (сухой остаток)            мг/дм3
# 13            Окисляемость перманганатная            мг/дм3
#
#     Результат анализа         Норматив
# 0                 8.4   в пределах 6-9
# 1                   1     не более 2-3
# 2             б/цвета      не более 30
# 3   9.199999999999999  в пределах 7-10
# 4                0.42     не более 1,5
# 5               0.017     не более 3,3
# 6                  24      не более 45
# 7                0.36     не более 3,5
# 8                 200     не более 350
# 9               189.5     не более 500
# 10              0.019     не более 0,3
# 11               0.55     не более 0,3
# 12                590    не более 1000
# 13                  2     не более 0,5

# %% [markdown]
# * Берем за основу что
# * "в пределах" означает от X до Y (оба показатели включительно)
# * "не более" означает от 0 до N (включительно)

# %%
# Ваше решение

# Обозначаем Минимумы для всех показателей
df["MinLimit"] = [
    6, # pH
    0, # Запах
    0, # Цветность
    7, # Жёсткость
    0, # Аммиак и аммоний-ион (по азоту)
    0, # Нитриты (по NO2)
    0, # Нитраты (по NO3)	
    0, # Фосфаты (P)
    0, # Хлориды (Cl)
    0, # Сульфаты (SO4)
    0, # Железо (включая хлорное железо) по Fe	
    0, # Нефть
    0, # Общая минерализация (сухой остаток)	
    0, # Окисляемость перманганатная	мг/дм3
]

# Обозначаем Максимумы для всех показателей
df["MaxLimit"] = [
    9, # pH
    3, # Запах
    30, # Цветность
    10, # Жёсткость
    1.5, # Аммиак и аммоний-ион (по азоту)
    3.3, # Нитриты (по NO2)
    45, # Нитраты (по NO3)	
    3.5, # Фосфаты (P)
    350, # Хлориды (Cl)
    500, # Сульфаты (SO4)
    0.3, # Железо (включая хлорное железо) по Fe	
    0.3, # Нефть
    1000, # Общая минерализация (сухой остаток)	
    0.5, # Окисляемость перманганатная	мг/дм3
]

# Зная заранее что в столбце Цветность пользователь может проставить не числовое значение 
# Проверяем данное поле 

if df["Результат анализа"].loc[2] == "б/цвета":
    df["Результат анализа"].loc[2] = 0

# Меняем тип столбца Результат анализа со строки на числовые значения

df["Результат анализа"] = pd.to_numeric(df["Результат анализа"], downcast="float")
#df["Результат анализа"] = df["Результат анализа"].astype(np.float32)

# Создадим новый столбец Result, где 
# 1 - соответствует нормативу
# 0 - не соответсвует нормативу

df["Result"] = df.apply(lambda x: "Соответствует" if x["Результат анализа"] >= x["MinLimit"] and x["Результат анализа"] <= x["MaxLimit"] 
                        else "Не соответствует", axis=1)

# Делаем столбец "Показатель" индексовым
df.set_index("Показатель")
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH              8.400
# Запах                                             баллы              1.000
# Цветность                                       градусы              0.000
# Жёсткость                                   мг-эквл/дм3              9.200
# Аммиак и аммоний-ион (по азоту)                  мг/дм3              0.420
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3             24.000
# Фосфаты (P)                                      мг/дм3              0.360
# Хлориды (Cl)                                     мг/дм3            200.000
# Сульфаты (SO4)                                   мг/дм3            189.500
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3              0.550
# Общая минерализация (сухой остаток)              мг/дм3            590.000
# Окисляемость перманганатная                      мг/дм3              2.000
#
#                                               Норматив  MinLimit  MaxLimit  \
# Показатель
# pH                                      в пределах 6-9         6       9.0
# Запах                                     не более 2-3         0       3.0
# Цветность                                  не более 30         0      30.0
# Жёсткость                              в пределах 7-10         7      10.0
# Аммиак и аммоний-ион (по азоту)           не более 1,5         0       1.5
# Нитриты (по NO2)                          не более 3,3         0       3.3
# Нитраты (по NO3)                           не более 45         0      45.0
# Фосфаты (P)                               не более 3,5         0       3.5
# Хлориды (Cl)                              не более 350         0     350.0
# Сульфаты (SO4)                            не более 500         0     500.0
# Железо (включая хлорное железо) по Fe     не более 0,3         0       0.3
# Нефть                                     не более 0,3         0       0.3
# Общая минерализация (сухой остаток)      не более 1000         0    1000.0
# Окисляемость перманганатная               не более 0,5         0       0.5
#
#                                                  Result
# Показатель
# pH                                        Соответствует
# Запах                                     Соответствует
# Цветность                                 Соответствует
# Жёсткость                                 Соответствует
# Аммиак и аммоний-ион (по азоту)           Соответствует
# Нитриты (по NO2)                          Соответствует
# Нитраты (по NO3)                          Соответствует
# Фосфаты (P)                               Соответствует
# Хлориды (Cl)                              Соответствует
# Сульфаты (SO4)                            Соответствует
# Железо (включая хлорное железо) по Fe     Соответствует
# Нефть                                  Не соответствует
# Общая минерализация (сухой остаток)       Соответствует
# Окисляемость перманганатная            Не соответствует

# %% [markdown]
# ## Теория вероятности. События
#
# Требуется сгенерировать необходимые выборки и произвести по ним расчеты

# %% [markdown]
# ### Задача 2
# В ящике 5 апельсинов и 4 яблока. Наудачу выбираются 3 фрукта. Какова вероятность, что все три фрукта – апельсины?
#
# В интернете полученный аналитически ответ 0.119. Подтверждается ли он эксперементально?

# %%
# Ваше решение

# Заполняем ящик необходимыми фруктами
inbox = ["Апельсин"] * 5 + ["Яблоко"] * 4 

# Добавим хаоса :) 
np.random.shuffle(inbox)

import random

# По очереди рандомно вытаскиваем фрукт, параметр Replace нужен чтобы один и тот же фрукт нельзя было выбрать 2 раза (фрукт обратно в ящик мы не помещаем) 
cases = [np.random.choice(inbox, size=3, replace=False) for _ in range(100000)]

df = pd.DataFrame(cases,columns = ['FirstTry', 'SecondTry', 'ThirdTry'])

#  Ищем все случаи когда вытащили именно 3 апельсина 
df_triple = df[ (df["FirstTry"] == "Апельсин") & (df["SecondTry"] == "Апельсин") & (df["ThirdTry"] == "Апельсин")]

len_total = len(df)
len_triple = len(df_triple)

len_total
len_triple
# Делим количество случаев 3 апельсинов подряд на общее количество 
len_triple/len_total
# Out:
# 1000000
# 119451
# 0.119451

# %% [markdown]
# ### Задача 3
# Мастер, имея 10 деталей, из которых 3 – нестандартных, проверяет детали одну за другой, пока ему не попадется стандартная. Какова вероятность, что он проверит ровно две детали?
#
#
# В интернете полученный аналитически ответ 7/30 или 0.23333. Подтверждается ли он эксперементально?

# %%
# Ваше решение

# Заполняем ящик необходимыми 10 деталями, назовём их Стандарт и Дефект
inbox = ["Стандарт"] * 7 + ["Дефект"] * 3 

# Добавим хаоса :) 
np.random.shuffle(inbox)

cases = [np.random.choice(inbox, 2, replace=False) for _ in range(100000)]

df = pd.DataFrame(cases,columns = ['FirstTry', 'SecondTry'])

# Считаем что под требованием проверить ровно 2 детали - значит мастеру сначала попалась Дефектная, а при следующей попытке попалась Стандартная
df_double = df[ (df["FirstTry"] == "Дефект") & (df["SecondTry"] == "Стандарт") ]

len_total = len(df)
len_double = len(df_double)

len_total
len_double
# Делим количество случаев Дефект-Стандарт подряд на общее количество 
len_double/len_total
# Out:
# 100000
# 23396
# 0.23396
